# %%
import numpy as np
import pandas as pd

# %%
data = "https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv"

# %%
df=pd.read_csv(data)

# %%
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# 3            16.912736
# 4            12.488369

# %%
df.fuel_efficiency_mpg
# Out:
# 0       13.231729
# 1       13.688217
# 2       14.246341
# 3       16.912736
# 4       12.488369
#           ...
# 9699    15.101802
# 9700    17.962326
# 9701    17.186587
# 9702    15.331551
# 9703    14.884467
# Name: fuel_efficiency_mpg, Length: 9704, dtype: float64

# %%
df.columns
# Out:
# Index(['engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'model_year', 'origin', 'fuel_type', 'drivetrain',
#        'num_doors', 'fuel_efficiency_mpg'],
#       dtype='object')

# %%
df.columns.str.lower().str.replace(" ","_")
# Out:
# Index(['engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'model_year', 'origin', 'fuel_type', 'drivetrain',
#        'num_doors', 'fuel_efficiency_mpg'],
#       dtype='object')

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# 1             17.8        2007     USA  Gasoline  Front-wheel drive
# 2             15.1        2018  Europe  Gasoline  Front-wheel drive
# 3             20.2        2009     USA    Diesel    All-wheel drive
# 4             14.4        2009  Europe  Gasoline    All-wheel drive
# ...            ...         ...     ...       ...                ...
# 9699          17.3        2013  Europe    Diesel  Front-wheel drive
# 9700          15.0        2004     USA  Gasoline    All-wheel drive
# 9701          15.1        2008     USA    Diesel    All-wheel drive
# 9702          19.4        2011     USA    Diesel  Front-wheel drive
# 9703          14.7        2005    Asia    Diesel    All-wheel drive
#
#       num_doors  fuel_efficiency_mpg
# 0           0.0            13.231729
# 1           0.0            13.688217
# 2           0.0            14.246341
# 3           2.0            16.912736
# 4           2.0            12.488369
# ...         ...                  ...
# 9699        NaN            15.101802
# 9700        0.0            17.962326
# 9701       -1.0            17.186587
# 9702        1.0            15.331551
# 9703       -1.0            14.884467
#
# [9704 rows x 11 columns]

# %%
df.dtypes
# Out:
# engine_displacement      int64
# num_cylinders          float64
# horsepower             float64
# vehicle_weight         float64
# acceleration           float64
# model_year               int64
# origin                  object
# fuel_type               object
# drivetrain              object
# num_doors              float64
# fuel_efficiency_mpg    float64
# dtype: object

# %%
strings = list(df.dtypes[df.dtypes == 'object'].index)
strings
# Out:
# ['origin', 'fuel_type', 'drivetrain']

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(' ','_')

# %%
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  europe  gasoline    all-wheel_drive        0.0
# 1          17.8        2007     usa  gasoline  front-wheel_drive        0.0
# 2          15.1        2018  europe  gasoline  front-wheel_drive        0.0
# 3          20.2        2009     usa    diesel    all-wheel_drive        2.0
# 4          14.4        2009  europe  gasoline    all-wheel_drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# 3            16.912736
# 4            12.488369

# %%
df.dtypes
# Out:
# engine_displacement      int64
# num_cylinders          float64
# horsepower             float64
# vehicle_weight         float64
# acceleration           float64
# model_year               int64
# origin                  object
# fuel_type               object
# drivetrain              object
# num_doors              float64
# fuel_efficiency_mpg    float64
# dtype: object

# %% [markdown]
# # 2.3 Exploratory data analysis

# %%
df.columns
# Out:
# Index(['engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'model_year', 'origin', 'fuel_type', 'drivetrain',
#        'num_doors', 'fuel_efficiency_mpg'],
#       dtype='object')

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# engine_displacement
# [170 130 220 210 190]
# 36
#
# num_cylinders
# [ 3.  5. nan  4.  1.]
# 14
#
# horsepower
# [159.  97.  78.  nan 140.]
# 192
#
# vehicle_weight
# [3413.43375861 3149.66493422 3079.03899737 2542.39240183 3460.87098999]
# 9704
#
# acceleration
# [17.7 17.8 15.1 20.2 14.4]
# 162
#
# model_year
# [2003 2007 2018 2009 2008]
# 24
#
# origin
# ['europe' 'usa' 'asia']
# 3
#
# fuel_type
# ['gasoline' 'diesel']
# 2
#
# drivetrain
# ['all-wheel_drive' 'front-wheel_drive']
# 2
#
# num_doors
# [ 0.  2. -1.  1. nan]
# 9
#
# fuel_efficiency_mpg
# [13.23172891 13.68821744 14.246341   16.9127356  12.48836912]
# 9704

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  europe  gasoline    all-wheel_drive
# 1             17.8        2007     usa  gasoline  front-wheel_drive
# 2             15.1        2018  europe  gasoline  front-wheel_drive
# 3             20.2        2009     usa    diesel    all-wheel_drive
# 4             14.4        2009  europe  gasoline    all-wheel_drive
# ...            ...         ...     ...       ...                ...
# 9699          17.3        2013  europe    diesel  front-wheel_drive
# 9700          15.0        2004     usa  gasoline    all-wheel_drive
# 9701          15.1        2008     usa    diesel    all-wheel_drive
# 9702          19.4        2011     usa    diesel  front-wheel_drive
# 9703          14.7        2005    asia    diesel    all-wheel_drive
#
#       num_doors  fuel_efficiency_mpg
# 0           0.0            13.231729
# 1           0.0            13.688217
# 2           0.0            14.246341
# 3           2.0            16.912736
# 4           2.0            12.488369
# ...         ...                  ...
# 9699        NaN            15.101802
# 9700        0.0            17.962326
# 9701       -1.0            17.186587
# 9702        1.0            15.331551
# 9703       -1.0            14.884467
#
# [9704 rows x 11 columns]

# %%
df= df[['engine_displacement', 'horsepower', 'vehicle_weight', 'model_year', 'fuel_efficiency_mpg']]

# %%
df
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  \
# 0                     170       159.0     3413.433759        2003
# 1                     130        97.0     3149.664934        2007
# 2                     170        78.0     3079.038997        2018
# 3                     220         NaN     2542.392402        2009
# 4                     210       140.0     3460.870990        2009
# ...                   ...         ...             ...         ...
# 9699                  140       164.0     2981.107371        2013
# 9700                  180       154.0     2439.525729        2004
# 9701                  220       138.0     2583.471318        2008
# 9702                  230       177.0     2905.527390        2011
# 9703                  270       140.0     2908.043477        2005
#
#       fuel_efficiency_mpg
# 0               13.231729
# 1               13.688217
# 2               14.246341
# 3               16.912736
# 4               12.488369
# ...                   ...
# 9699            15.101802
# 9700            17.962326
# 9701            17.186587
# 9702            15.331551
# 9703            14.884467
#
# [9704 rows x 5 columns]

# %%
df.head()
# Out:
#    engine_displacement  horsepower  vehicle_weight  model_year  \
# 0                  170       159.0     3413.433759        2003
# 1                  130        97.0     3149.664934        2007
# 2                  170        78.0     3079.038997        2018
# 3                  220         NaN     2542.392402        2009
# 4                  210       140.0     3460.870990        2009
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# 3            16.912736
# 4            12.488369

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.histplot(df.fuel_efficiency_mpg, bins=30)
# Out:
# <Axes: xlabel='fuel_efficiency_mpg', ylabel='Count'>

# %% [markdown]
# # does it have a long tail ? NO

# %% [markdown]
# # Question 1
# There's one column with missing values. What is it?

# %%
df.isnull().sum()
# Out:
# engine_displacement      0
# horsepower             708
# vehicle_weight           0
# model_year               0
# fuel_efficiency_mpg      0
# dtype: int64

# %% [markdown]
# # Question 2
# What's the median (50% percentile) for variable 'horsepower'?

# %%
df.horsepower.median()
# Out:
# 149.0

# %%
df.horsepower.mean()
# Out:
# 149.65729212983547

# %% [markdown]
# Prepare and split the dataset
# Shuffle the dataset (the filtered one you created above), use seed 42.
# Split your data in train/val/test sets, with 60%/20%/20% distribution.

# %%
n = len(df)

n_val = int(n*0.2)
n_test= int(n*0.2)
n_train = n - n_val - n_test

# %%
 n_val ,n_test ,n_train
# Out:
# (1940, 1940, 5824)

# %%
df.iloc[10:]
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  \
# 10                    230       100.0     3111.810181        2014
# 11                    150         NaN     1967.200421        2014
# 12                    320       145.0     2783.868974        2010
# 13                    170       193.0     2274.735191        2000
# 14                    200       160.0     3582.687368        2007
# ...                   ...         ...             ...         ...
# 9699                  140       164.0     2981.107371        2013
# 9700                  180       154.0     2439.525729        2004
# 9701                  220       138.0     2583.471318        2008
# 9702                  230       177.0     2905.527390        2011
# 9703                  270       140.0     2908.043477        2005
#
#       fuel_efficiency_mpg
# 10              13.386605
# 11              20.504447
# 12              16.175820
# 13              18.792742
# 14              11.871091
# ...                   ...
# 9699            15.101802
# 9700            17.962326
# 9701            17.186587
# 9702            15.331551
# 9703            14.884467
#
# [9694 rows x 5 columns]

# %%
df_train = df.iloc[:n_train]
df_val = df.iloc[n_train:n_train+n_val]
df_test  = df.iloc[n_train+n_val:]

# %%
df_val
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  \
# 5824                  190       154.0     3155.165485        2019
# 5825                  160       134.0     3401.093783        2007
# 5826                  160       164.0     3799.748282        2004
# 5827                  170       140.0     3508.135917        2001
# 5828                   60       169.0     2289.214556        2010
# ...                   ...         ...             ...         ...
# 7759                  170       104.0     3658.729114        2011
# 7760                  210       144.0     2007.295032        2018
# 7761                  230       167.0     3204.388711        2002
# 7762                  170       109.0     4126.979051        2016
# 7763                  190         NaN     1667.097298        2020
#
#       fuel_efficiency_mpg
# 5824            14.240172
# 5825            13.962501
# 5826            11.426805
# 5827            11.832029
# 5828            18.443872
# ...                   ...
# 7759            11.653651
# 7760            19.564821
# 7761            14.120344
# 7762             9.080170
# 7763            21.114107
#
# [1940 rows x 5 columns]

# %%
df_test
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  \
# 7764                  210       136.0     3001.227490        2004
# 7765                  290       142.0     3190.590332        2010
# 7766                  240       120.0     3518.444921        2008
# 7767                  220       141.0     1909.631801        2015
# 7768                  170       114.0     3825.442821        2009
# ...                   ...         ...             ...         ...
# 9699                  140       164.0     2981.107371        2013
# 9700                  180       154.0     2439.525729        2004
# 9701                  220       138.0     2583.471318        2008
# 9702                  230       177.0     2905.527390        2011
# 9703                  270       140.0     2908.043477        2005
#
#       fuel_efficiency_mpg
# 7764            14.272374
# 7765            14.562889
# 7766            11.872658
# 7767            19.731391
# 7768            10.344815
# ...                   ...
# 9699            15.101802
# 9700            17.962326
# 9701            17.186587
# 9702            15.331551
# 9703            14.884467
#
# [1940 rows x 5 columns]

# %%
df_train
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  \
# 0                     170       159.0     3413.433759        2003
# 1                     130        97.0     3149.664934        2007
# 2                     170        78.0     3079.038997        2018
# 3                     220         NaN     2542.392402        2009
# 4                     210       140.0     3460.870990        2009
# ...                   ...         ...             ...         ...
# 5819                  160       156.0     2990.334203        2020
# 5820                  240       105.0     3495.100812        2014
# 5821                  210       171.0     3434.252180        2011
# 5822                  180       172.0     2967.708852        2018
# 5823                  180       152.0     2483.544520        2014
#
#       fuel_efficiency_mpg
# 0               13.231729
# 1               13.688217
# 2               14.246341
# 3               16.912736
# 4               12.488369
# ...                   ...
# 5819            15.294958
# 5820            12.426054
# 5821            12.509291
# 5822            14.746571
# 5823            16.848448
#
# [5824 rows x 5 columns]

# %%
idx = np.arange(n)

# %%
np.random.seed(42)
np.random.shuffle(idx)

# %%
idx
# Out:
# array([ 483, 7506, 8795, ..., 5390,  860, 7270])

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train+n_val]]
df_test  = df.iloc[idx[n_train+n_val:]]

# %%
df_train.head()
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  \
# 483                   220       144.0     2535.887591        2009
# 7506                  160       141.0     2741.170484        2019
# 8795                  230       155.0     2471.880237        2017
# 1688                  150       206.0     3748.164469        2015
# 6217                  300       111.0     2135.716359        2006
#
#       fuel_efficiency_mpg
# 483             16.642943
# 7506            16.298377
# 8795            18.591822
# 1688            11.818843
# 6217            19.402209

# %%
len(df_train),len(df_val),len(df_test)
# Out:
# (5824, 1940, 1940)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
df_train
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  \
# 0                     220       144.0     2535.887591        2009
# 1                     160       141.0     2741.170484        2019
# 2                     230       155.0     2471.880237        2017
# 3                     150       206.0     3748.164469        2015
# 4                     300       111.0     2135.716359        2006
# ...                   ...         ...             ...         ...
# 5819                  260       139.0     2606.972984        2009
# 5820                  280       132.0     4004.214323        2014
# 5821                  210       152.0     2500.175687        2020
# 5822                  250       154.0     2254.313245        2002
# 5823                  210       152.0     2435.203606        2004
#
#       fuel_efficiency_mpg
# 0               16.642943
# 1               16.298377
# 2               18.591822
# 3               11.818843
# 4               19.402209
# ...                   ...
# 5819            16.964054
# 5820            10.059094
# 5821            17.593237
# 5822            18.925748
# 5823            17.965284
#
# [5824 rows x 5 columns]

# %%
df_val
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  \
# 0                     180       112.0     2772.134410        2020
# 1                     260       138.0     3014.061530        2022
# 2                     140       181.0     3652.186151        2016
# 3                     270       105.0     2753.040847        2023
# 4                     170       224.0     4163.375137        2003
# ...                   ...         ...             ...         ...
# 1935                  290       205.0     3403.401496        2019
# 1936                  200       159.0     2752.516039        2009
# 1937                  230       202.0     3303.000688        2008
# 1938                  220       169.0     3293.420251        2008
# 1939                  200       117.0     2692.781292        2004
#
#       fuel_efficiency_mpg
# 0               15.366341
# 1               14.601182
# 2               12.247032
# 3               15.136400
# 4               10.340419
# ...                   ...
# 1935            13.868607
# 1936            15.665403
# 1937            13.613127
# 1938            13.733343
# 1939            15.816050
#
# [1940 rows x 5 columns]

# %%
df_test
# Out:
#       engine_displacement  horsepower  vehicle_weight  model_year  \
# 0                     140       148.0     2704.826005        2017
# 1                     210       136.0     3001.227490        2004
# 2                     210       152.0     3747.467392        2021
# 3                     190       128.0     2705.833636        2014
# 4                     230       156.0     2505.939657        2005
# ...                   ...         ...             ...         ...
# 1935                  210       163.0     1972.029124        2011
# 1936                  160       126.0     3011.588014        2009
# 1937                  290       187.0     2440.508039        2019
# 1938                  260       129.0     1865.404480        2019
# 1939                  270       147.0     2611.939500        2017
#
#       fuel_efficiency_mpg
# 0               15.804354
# 1               14.272374
# 2               11.748441
# 3               16.485991
# 4               17.779704
# ...                   ...
# 1935            19.961672
# 1936            14.651056
# 1937            18.404435
# 1938            20.502460
# 1939            16.816241
#
# [1940 rows x 5 columns]

# %%
y_train = df_train.fuel_efficiency_mpg.values
y_val = df_val.fuel_efficiency_mpg.values
y_test = df_test.fuel_efficiency_mpg.values

# %%
del df_train['fuel_efficiency_mpg']
del df_val['fuel_efficiency_mpg']
del df_test['fuel_efficiency_mpg']

# %%
len(y_train)
# Out:
# 5824

# %% [markdown]
# # linear regression

# %%
df_train.iloc[10]
# Out:
# engine_displacement     240.000000
# horsepower              159.000000
# vehicle_weight         2916.987921
# model_year             2001.000000
# Name: 10, dtype: float64

# %%
xi= [3064,161,110]
w0 = 7.17
w = [0.01, 0.04, 0.002]

# %%
def linear_regression(xi):
    n = len(xi)

    pred = w0

    for j in range(n):
        pred = pred + w[j] * xi[j]

    return pred

# %%
xi = [3064,161,110]
w0 = 7.17
w = [0.01, 0.04, 0.002]

# %%
linear_regression(xi)
# Out:
# 44.47

# %%
np.expm1(44.47)
# Out:
# 2.0562485556526432e+19

# %%
np.log1p(2.0562485556526432e+19)
# Out:
# 44.47

# %% [markdown]
# # Linear regression vector form

# %%
def dot(xi,w):
    n = len(xi)
    
    res = 0.0
    
    for j in range(n):
        res = res + xi[j] * w[j]
        
    return res

# %%
def linear_regression(xi):
    return w0 + dot(xi,w)

# %%
w_new = [w0] + w

# %%
w_new
# Out:
# [7.17, 0.01, 0.04, 0.002]

# %%
def linear_regression(xi):
    xi = [1] + xi
    return dot(xi, w_new)

# %%
linear_regression(xi)
# Out:
# 44.47

# %%
w0 = 7.17
w = [0.01, 0.04, 0.002]
w_new = [w0] + w

# %%
xi = [3064,161,110]
w0 = 7.17
w = [0.01, 0.04, 0.002]

# %%
x1  = [1, 148, 24, 1385]
x2  = [1, 132, 25, 2031]
x10 = [1, 3064,161,110]

X = [x1, x2, x10]
X = np.array(X)
X
# Out:
# array([[   1,  148,   24, 1385],
#        [   1,  132,   25, 2031],
#        [   1, 3064,  161,  110]])

# %%
def linear_regression(X):
    return X.dot(w_new)

# %%
linear_regression(X)
# Out:
# array([12.38 , 13.552, 44.47 ])

# %% [markdown]
# # Training a linear regression model

# %%
def train_linear_regression(X, y):
    pass

# %%
X = [
    [148, 24, 135],
    [132, 25, 2031],
    [43, 11, 86],
    [158, 24, 185],
    [172, 25, 201],
    [413, 11, 86],
    [38,  54, 185],
    [142, 25, 431],
    [453, 31, 86],
]

X = np.array(X)
X
# Out:
# array([[ 148,   24,  135],
#        [ 132,   25, 2031],
#        [  43,   11,   86],
#        [ 158,   24,  185],
#        [ 172,   25,  201],
#        [ 413,   11,   86],
#        [  38,   54,  185],
#        [ 142,   25,  431],
#        [ 453,   31,   86]])

# %%
ones = np.ones(X.shape[0])
ones
# Out:
# array([1., 1., 1., 1., 1., 1., 1., 1., 1.])

# %%
X = np.column_stack([ones, X])

# %%
y = [10000, 20000, 15000, 20050, 10000, 20000, 15000, 25000, 12000]

# %%
XTX = X.T.dot(X)
XTX_inv = np.linalg.inv(XTX)
w_full = XTX_inv.dot(X.T).dot(y)

# %%
w0 = w_full[0]
w = w_full[1:]

# %%
w0, w
# Out:
# (17453.485793689448, array([ -0.93788815, -80.42001915,   2.93599073]))

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)
    
    return w_full[0], w_full[1:]

# %%
train_linear_regression(X, y)
# Out:
# (4.092504066933571e+20,
#  array([-4.09250407e+20, -3.28830497e+01, -6.88143091e+03,  1.41603947e+00]))

# %% [markdown]
# # Baseline model

# %%
df_train.columns
# Out:
# Index(['engine_displacement', 'horsepower', 'vehicle_weight', 'model_year'], dtype='object')

# %%
base = ['engine_displacement', 'horsepower', 'vehicle_weight', 'model_year']


X_train = df_train[base].fillna(0).values

w0,w = train_linear_regression(X_train_0, y_train)

y_pred = w0 + X_train_0.dot(w)

# %%
X_train = df_train[base].values

# %%
df.horsepower.mean()
# Out:
# 149.65729212983547

# %%
X_train_mean = df_train[base].fillna(149.6)

# %%
df.horsepower.mean()
# Out:
# 149.65729212983547

# %%
X_train = df_train[base].fillna(0).values

# %%
df.horsepower.mean()
# Out:
# 149.65729212983547

# %%
train_linear_regression(X_train, y_train)
# Out:
# (28.8273654746102,
#  array([ 9.93613218e-05,  3.54221891e-03, -5.01328015e-03,  3.42992869e-04]))

# %%
#train_linear_regression(X_train_mean, y_train)

# %%
w0,w = train_linear_regression(X_train, y_train)

# %%
y_pred = w0 + X_train.dot(w)

# %%
sns.histplot(y_pred,color ='red',alpha=0.5 ,bins = 50)
sns.histplot(y_train, color ='blue',alpha=0.5,bins = 50)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # RMSE

# %%
def rmse(y,y_pred):
    se = (y - y_pred) **2
    mse = se.mean()
    return np.sqrt(mse)

# %%
rmse(y_train,y_pred)
# Out:
# 0.5202614265099076

# %% [markdown]
# # Validating the model

# %%
base = ['engine_displacement', 'horsepower', 'vehicle_weight', 'model_year']


X_train = df_train[base].fillna(0).values

w0,w = train_linear_regression(X_train, y_train)

y_pred = w0 + X_train.dot(w)

# %%
def prepare_X(df):
    df_num = df[base]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w0,w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# 0.5173782638845121

# %% [markdown]
# # Simple feature engineering

# %%
2023 - df_train.model_year
# Out:
# 0       14
# 1        4
# 2        6
# 3        8
# 4       17
#         ..
# 5819    14
# 5820     9
# 5821     3
# 5822    21
# 5823    19
# Name: model_year, Length: 5824, dtype: int64

# %%
def prepare_X(df):
    df = df.copy()
    
    df['age'] = 2023 - df['model_year']
    features = base + ['age']
    
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
X_train = prepare_X(df_train)
w0,w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
                  
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# 29.515420191675066

# %%
sns.histplot(y_pred, label='prediction', color='red', alpha=0.5, bins=50)
sns.histplot(y_val, label='target', color='blue',  alpha=0.5, bins=50)
plt.legend()

# %%
categorical_columns = [
    'engine_displacement',
'horsepower',
'vehicle_weight',
'model_year',
]

categorical = {}

for c in categorical_columns:
    categorical[c] = list(df_train[c].value_counts().head().index)

# %%
def prepare_X(df):
    df = df.copy()
    
    df['age'] = 2023 - df['model_year']
    features = base + ['age']

   

    for name, values in categorical.items():
        for value in values:
            df['%s_%s' % (name, value)] = (df[name] == value).astype(int)
            features.append('%s_%s' % (name, value))

    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
X_train = prepare_X(df_train)
w0,w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
                  
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# 6.851984573233703

# %%
w0, w
# Out:
# (-11.538071446721538,
#  array([ 1.43159755e-04,  3.52323047e-03, -5.00866401e-03,  1.69123142e-02,
#          1.66074135e-02, -9.71175854e-03,  2.68867091e-02,  1.09268058e-02,
#          2.93515187e-02, -1.07432100e-02,  6.87992240e-03, -2.00096813e-01,
#          1.12489467e-02, -1.55563048e-01,  4.91582756e-02, -7.35206192e-01,
#         -4.71167752e-01, -1.05999774e+00,  6.54817810e-01, -2.20282545e-01,
#         -5.13417565e-02, -6.19375646e-02, -4.94999872e-02, -3.09506605e-02,
#         -2.72679713e-02]))

# %% [markdown]
# # Regularization

# %%
X = [
    [4, 4, 4.001],
    [3, 5, 5],
    [5, 1.001, 1],
    [5, 4, 4],
    [7, 5, 5],
    [4, 5, 5.00000001],
]

X = np.array(X)
X
# Out:
# array([[4.        , 4.        , 4.001     ],
#        [3.        , 5.        , 5.        ],
#        [5.        , 1.001     , 1.        ],
#        [5.        , 4.        , 4.        ],
#        [7.        , 5.        , 5.        ],
#        [4.        , 5.        , 5.00000001]])

# %%
y= [1, 2, 3, 1, 2, 3]

# %%
XTX = X.T.dot(X)
XTX
# Out:
# array([[140.        , 111.005     , 111.00400004],
#        [111.005     , 108.002001  , 108.00500005],
#        [111.00400004, 108.00500005, 108.0080011 ]])

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
XTX_inv
# Out:
# array([[ 5.80940879e-02, -1.23796975e+02,  1.23733829e+02],
#        [-1.23796975e+02,  7.85561430e+05, -7.85412372e+05],
#        [ 1.23733829e+02, -7.85412372e+05,  7.85263392e+05]])

# %%
XTX_inv.dot(X.T).dot(y)
# Out:
# array([ 1.00931988e-01,  1.49529083e+03, -1.49492711e+03])

# %%
XTX = [
    [1, 2, 2],
    [2, 1, 1.0000001],
    [2, 1.0000001, 1]
]

XTX = np.array(XTX)

# %%
np.linalg.inv(XTX)
# Out:
# array([[-3.33333356e-01,  3.33333339e-01,  3.33333339e-01],
#        [ 3.33333339e-01, -5.00000008e+06,  4.99999991e+06],
#        [ 3.33333339e-01,  4.99999991e+06, -5.00000008e+06]])

# %%
XTX = XTX + 0.01 * np.eye(3)

# %%
np.linalg.inv(XTX)
# Out:
# array([[ -0.33668908,   0.33501399,   0.33501399],
#        [  0.33501399,  49.91590897, -50.08509104],
#        [  0.33501399, -50.08509104,  49.91590897]])

# %%
def train_linear_regression_reg(X, y, r=0.001):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    XTX = XTX + r * np.eye(XTX.shape[0])

    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)
    
    return w_full[0], w_full[1:]

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression_reg(X_train, y_train, r=0.01)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# 0.5187462072457798

# %% [markdown]
# # Tuning the model

# %%
for r in [0.0, 0.00001, 0.0001, 0.001, 0.1, 1, 10]:
    X_train = prepare_X(df_train)
    w0, w = train_linear_regression_reg(X_train, y_train, r=r)

    X_val = prepare_X(df_val)
    y_pred = w0 + X_val.dot(w)
    score = rmse(y_val, y_pred)
    
    print(r, w0, score)
# Out:
# 0.0 -11.538071446721538 6.851984573233703
# 1e-05 2.477522537769023e-05 0.5187465040701092
# 0.0001 1.424478900537026e-05 0.5187464787603823
# 0.001 1.4853779219993307e-05 0.5187464572030643
# 0.1 1.485006825975807e-05 0.5187437928398884
# 1 1.4849125044660493e-05 0.5187238808286696
# 10 1.4815036904657678e-05 0.5185806278534535

# %%
r = 0.001
X_train = prepare_X(df_train)
w0, w = train_linear_regression_reg(X_train, y_train, r=r)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
score = rmse(y_val, y_pred)
score
# Out:
# 0.5187464572030643

# %% [markdown]
# # Using the model

# %%
df_full_train = pd.concat([df_train, df_val])

# %%
df_full_train = df_full_train.reset_index(drop=True)

# %%
X_full_train = prepare_X(df_full_train)

# %%
X_full_train
# Out:
# array([[2.20000000e+02, 1.44000000e+02, 2.53588759e+03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.60000000e+02, 1.41000000e+02, 2.74117048e+03, ...,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [2.30000000e+02, 1.55000000e+02, 2.47188024e+03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [2.30000000e+02, 2.02000000e+02, 3.30300069e+03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.20000000e+02, 1.69000000e+02, 3.29342025e+03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.00000000e+02, 1.17000000e+02, 2.69278129e+03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
y_full_train = np.concatenate([y_train, y_val])

# %%
w0, w = train_linear_regression_reg(X_full_train, y_full_train, r=0.001)

# %%
X_test = prepare_X(df_test)
y_pred = w0 + X_test.dot(w)
score = rmse(y_test, y_pred)
score
# Out:
# 0.5166339533024112

# %%
car = df_test.iloc[20].to_dict()
car
# Out:
# {'engine_displacement': 160.0,
#  'horsepower': 125.0,
#  'vehicle_weight': 3317.04204639791,
#  'model_year': 2018.0}

# %%
df_small = pd.DataFrame([car])
df_small
# Out:
#    engine_displacement  horsepower  vehicle_weight  model_year
# 0                160.0       125.0     3317.042046      2018.0

# %%
X_small = prepare_X(df_small)

# %%
y_pred = w0 + X_small.dot(w)
y_pred = y_pred[0]
y_pred
# Out:
# 13.35078940482604

# %%
np.expm1(y_pred)
# Out:
# 628309.2831152603

# %%
np.expm1(y_test[20])
# Out:
# 354709.16315333516
