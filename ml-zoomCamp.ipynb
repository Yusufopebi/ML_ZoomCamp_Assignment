# %% [markdown]
# # Q1.importing necessary pages:

# %%
import numpy as np
import pandas as pd

# %%
#Q1. Pandas version

pd.__version__
# Out:
# '1.5.3'

# %%
data = 'https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv'

# %%
df = pd.read_csv(data)

# %% [markdown]
# # Q2. Records count

# %%
#How many records are in the dataset? 2160 
df
# Out:
#                                                  Laptop       Status   Brand  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
#            Model                CPU  RAM  Storage Storage type       GPU  \
# 0     ExpertBook      Intel Core i5    8      512          SSD       NaN
# 1             Go      Intel Celeron    8      256          SSD       NaN
# 2     ExpertBook      Intel Core i3    8      256          SSD       NaN
# 3         Katana      Intel Core i7   16     1000          SSD  RTX 3050
# 4            15S      Intel Core i5   16      512          SSD       NaN
# ...          ...                ...  ...      ...          ...       ...
# 2155       Blade      Intel Core i7   16     1000          SSD  RTX 3060
# 2156       Blade      Intel Core i7   16     1000          SSD  RTX 3070
# 2157       Blade      Intel Core i7   32     1000          SSD  RTX 3080
# 2158        Book  Intel Evo Core i7   16     1000          SSD       NaN
# 2159        Book  Intel Evo Core i7   16      256          SSD       NaN
#
#       Screen Touch  Final Price
# 0       15.6    No      1009.00
# 1       15.6    No       299.00
# 2       15.6    No       789.00
# 3       15.6    No      1199.00
# 4       15.6    No       669.01
# ...      ...   ...          ...
# 2155    17.3    No      2699.99
# 2156    17.3    No      2899.99
# 2157    17.3    No      3399.99
# 2158    13.4   Yes      1899.99
# 2159    13.4   Yes      1699.99
#
# [2160 rows x 12 columns]

# %% [markdown]
# # Q3. Laptop brands

# %%
#How many laptop brands are presented in the dataset? 2160
df['Laptop']
# Out:
# 0       ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...
# 1       Alurin Go Start Intel Celeron N4020/8GB/256GB ...
# 2       ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...
# 3       MSI Katana GF66 12UC-082XES Intel Core i7-1270...
# 4       HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...
#                               ...
# 2155    Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...
# 2156    Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...
# 2157    Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...
# 2158    Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...
# 2159    Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...
# Name: Laptop, Length: 2160, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2160, step=1)

# %% [markdown]
# # Q4. Missing values

# %%
# How many columns in the dataset have missing values? 3 columns
df.isnull().sum()
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen             4
# Touch              0
# Final Price        0
# dtype: int64

# %%
df.describe()
# Out:
#                RAM      Storage       Screen  Final Price
# count  2160.000000  2160.000000  2156.000000  2160.000000
# mean     15.413889   596.294444    15.168112  1312.638509
# std       9.867815   361.220506     1.203329   911.475417
# min       4.000000     0.000000    10.100000   201.050000
# 25%       8.000000   256.000000    14.000000   661.082500
# 50%      16.000000   512.000000    15.600000  1031.945000
# 75%      16.000000  1000.000000    15.600000  1708.970000
# max     128.000000  4000.000000    18.000000  7150.470000

# %%
df.to_dict(orient = 'records')
# Out:
# [{'Laptop': 'ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core i5-1235U/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ExpertBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1009.0},
#  {'Laptop': 'Alurin Go Start Intel Celeron N4020/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Alurin',
#   'Model': 'Go',
#   'CPU': 'Intel Celeron',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 299.0},
#  {'Laptop': 'ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core i3-1215U/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ExpertBook',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 789.0},
#  {'Laptop': 'MSI Katana GF66 12UC-082XES Intel Core i7-12700H/16GB/1TB SSD/RTX3050/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Katana',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1199.0},
#  {'Laptop': 'HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 669.01},
#  {'Laptop': 'MSI Crosshair 17 C12VF-264XES Intel Core i7-12650H/32GB/1TB SSD/RTX 4060/17.3"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Crosshair',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4060',
#   'Screen': 17.3,
#   'Touch': 'No',
#   'Final Price': 1699.0},
#  {'Laptop': 'Lenovo Thinkpad E14 Gen 4 AMD Ryzen 5 5625U/8GB/256GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'ThinkPad',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 909.0},
#  {'Laptop': 'ASUS VivoBook 15 F515JA-EJ2882W Intel Core i7-1065G7/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 809.01},
#  {'Laptop': 'Medion Akoya E15415 Intel Core i5-10210U/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Medion',
#   'Model': 'Akoya',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 519.0},
#  {'Laptop': 'HP Victus 16-d1038ns Intel Core i7-12700H/16GB/512GB SSD/RTX 3050/16.1"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Victus',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 16.1,
#   'Touch': 'No',
#   'Final Price': 1149.0},
#  {'Laptop': 'Lenovo V15 IGL Intel Celeron N4020/8GB/256 GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'V15',
#   'CPU': 'Intel Celeron',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 349.0},
#  {'Laptop': 'MSI Thin GF63 12VE-021XES Intel Core i7-12650H/16GB/1TB SSD/RTX 4050/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Thin',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1399.0},
#  {'Laptop': 'ASUS ROG Strix G15 G513RC-HN088 AMD Ryzen 7 6800H/16GB/512GB SSD/RTX 3050/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ROG',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1199.0},
#  {'Laptop': 'Lenovo V15 G3 ABA AMD Ryzen 5 5625U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'V15',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 476.99},
#  {'Laptop': 'Lenovo IdeaPad 1 15ADA7 AMD Ryzen 3 3250U/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 391.0},
#  {'Laptop': 'HP 15S-FQ5013NS Intel Core i5-1235U/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 699.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15IAU7 Intel Core i5-1235U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 799.0},
#  {'Laptop': 'HP 15S-FQ2163NS Intel Core i3-1115G4/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 549.0},
#  {'Laptop': 'ASUS VivoBook 15 F515JA-EJ4134 Intel Core i7-1065G7/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 769.0},
#  {'Laptop': 'MSI GF63 Thin 11UC-446XES Intel Core i7-11800H/16GB/512GB SSD/RTX 3050/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Thin',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 999.0},
#  {'Laptop': 'MSI Cyborg 15 A12VF-098XES Intel Core i5-12450H/16GB/1TB SSD/RTX 4060/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Cyborg',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4060',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1249.0},
#  {'Laptop': 'ASUS M515UA-EJ486W AMD Ryzen 7 5700U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'M515UA',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 789.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ALC6 AMD Ryzen 7 5700U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 729.0},
#  {'Laptop': 'ASUS TUF Gaming F15 FX506HC-HN004 Intel Core i5-11400H/16GB/512GB SSD/RTX 3050/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'TUF',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1099.0},
#  {'Laptop': 'Acer Aspire 3 A315-59-37GX Intel Core i3-1215U/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Acer',
#   'Model': 'Aspire',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 539.01},
#  {'Laptop': 'ASUS TUF Gaming F15 FX507ZC4-HN002 Intel Core i7-12700H/16GB/512GB SSD/RTX 3050/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'TUF',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1179.0},
#  {'Laptop': 'Alurin Go Start Intel Celeron N4020/8GB/256GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'Alurin',
#   'Model': 'Go',
#   'CPU': 'Intel Celeron',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 239.0},
#  {'Laptop': 'HP Victus 15-fa0012ns Intel Core i5-12500H/16GB/512GB SSD/RTX 3050/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Victus',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 999.0},
#  {'Laptop': 'HP Pavilion 15-eh1004ns AMD Ryzen 5 5500U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Pavilion',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 799.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ITL6 Intel Core i5-1155G7/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 519.01},
#  {'Laptop': 'HP 15S-FQ5028NS Intel Core i5-1235U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 789.0},
#  {'Laptop': 'MSI Katana 15 B12VFK-095XES Intel Core i7-12650H/16GB/512GB SSD/RTX 4060/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Katana',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4060',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1549.0},
#  {'Laptop': 'ASUS VivoBook F1500EA-EJ2384W Intel Core i3-1115G4/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 539.01},
#  {'Laptop': 'HP 15S-fq2159ns Intel Core i3-1115G4/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 539.0},
#  {'Laptop': 'MSI Vector GP77 13VF-022XES Intel Core i7-13700H/32GB/1TB SSD/RTX 4060/17.3"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Vector',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4060',
#   'Screen': 17.3,
#   'Touch': 'No',
#   'Final Price': 2249.0},
#  {'Laptop': 'ASUS VivoBook Pro 15 OLED M6500QC-L1010W AMD Ryzen 7 5800H/16GB/512GB SSD/RTX 3050/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1299.01},
#  {'Laptop': 'ASUS ROG Strix G15 G513RC-HF094 AMD Ryzen 7 6800H/16GB/512GB SSD/RTX3050/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ROG',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1139.01},
#  {'Laptop': 'ASUS Chromebook CX1500CNA-EJ0100 Intel Celeron N3350/8GB/64GB eMMC/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'Chromebook',
#   'CPU': 'Intel Celeron',
#   'RAM': 8,
#   'Storage': 64,
#   'Storage type': 'eMMC',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 399.0},
#  {'Laptop': 'HP 15S-fq5101ns Intel Core i7-1255U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 789.0},
#  {'Laptop': 'HP 15S-EQ2090NS AMD Ryzen 5 5500U/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 599.01},
#  {'Laptop': "HP Omen 16-b1022ns Intel Core i7-12700H/32GB/1TB SSD/RTX 3060/16.1''",
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Omen',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3060',
#   'Screen': 16.1,
#   'Touch': 'No',
#   'Final Price': 1699.0},
#  {'Laptop': 'ASUS VivoBook 15 F1502ZA-EJ733 Intel Core i5-1235U/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 609.0},
#  {'Laptop': 'Asus ZenBook 13 OLED UX325EA-KG245 Intel Core i7-1165G7/16GB/512GB SSD/13.3"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ZenBook',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 13.3,
#   'Touch': 'No',
#   'Final Price': 1089.0},
#  {'Laptop': "HP Victus 16-d1033ns Intel Core i7-12700H/16GB/512GB SSD/RTX 3060/16.1''",
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Victus',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3060',
#   'Screen': 16.1,
#   'Touch': 'No',
#   'Final Price': 1399.0},
#  {'Laptop': 'HP 15S-fq5055ns Intel Core i7-1255U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 899.01},
#  {'Laptop': 'HP 15S-eq2087ns AMD Ryzen 5 5500U/12GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 12,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 549.0},
#  {'Laptop': 'Lenovo IdeaPad Gaming 3 15IHU6 Intel Core i5-11320H/16GB/512GB SSD/RTX3050/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 929.0},
#  {'Laptop': 'MSI Creator M16 B13VE-682XES Intel Core i7-13700H/32GB/1TB SSD/RTX 4050/16"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Creator',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4050',
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 1899.01},
#  {'Laptop': 'Lenovo IdeaPad 1 15ALC7 AMD Ryzen 7 5700U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 829.0},
#  {'Laptop': 'HP 15S-fq2158ns Intel Core i3-1115G4/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 449.0},
#  {'Laptop': 'Apple MacBook Air Apple M1/8GB/256GB SSD/GPU Hepta Core/13.3" Gris Espacial',
#   'Status': 'New',
#   'Brand': 'Apple',
#   'Model': 'MacBook Air',
#   'CPU': 'Apple M1',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 13.3,
#   'Touch': 'No',
#   'Final Price': 1219.0},
#  {'Laptop': 'Lenovo ThinkBook 14 Intel Core i5-1135G7/8GB/256GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'ThinkBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 699.0},
#  {'Laptop': 'ASUS TUF Gaming A15 2023 FA507NV-LP041 AMD Ryzen 7 7735HS/16GB/1TB SSD/RTX 4060/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'TUF',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4060',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1349.0},
#  {'Laptop': 'MSI Katana 15 B12VGK-094XES Intel Core i7-12650H/16GB/1TB SSD/RTX 4070/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Katana',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4070',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1699.0},
#  {'Laptop': 'ASUS M515UA-EJ522W AMD Ryzen 5 5500U/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'M515UA',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 699.0},
#  {'Laptop': 'HP Victus 16-e0101ns AMD Ryzen 7 5800H/16GB/512GB SSD/RTX 3060/16.1"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Victus',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3060',
#   'Screen': 16.1,
#   'Touch': 'No',
#   'Final Price': 1299.01},
#  {'Laptop': 'HP 250 G9 Intel Celeron N4500/8 GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '250',
#   'CPU': 'Intel Celeron',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 399.0},
#  {'Laptop': 'HP OMEN 16-C0042NS AMD Ryzen 7 5800H/16GB/512GB SSD/RTX 3050 Ti/16.1"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Omen',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 16.1,
#   'Touch': 'No',
#   'Final Price': 1149.0},
#  {'Laptop': 'MSI Modern 15 B7M-041XES AMD Ryzen 5 7530U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Modern',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 839.0},
#  {'Laptop': 'HP 255 G9 AMD Athlon 3020e/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '255',
#   'CPU': 'AMD Athlon',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 379.0},
#  {'Laptop': 'ASUS VivoBook 15 F1500EA-EJ3022 Intel Core i7-1165G7/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 809.01},
#  {'Laptop': 'Lenovo V15 G2 ITL Intel Core i5-1135G7/8 GB/512 GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'V15',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 779.0},
#  {'Laptop': 'ASUS VivoBook 15 F1500EA-EJ3023 Intel Core i7-1165G7/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 749.0},
#  {'Laptop': 'MSI Thin GF63 12VE-009XES Intel Core i5-12450H/16GB/512GB SSD/RTX 4050/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Thin',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1099.0},
#  {'Laptop': 'MSI Modern 15 B13M-281XES Intel Core i7-1355U/16GB/1TB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Modern',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 999.0},
#  {'Laptop': 'HP 15S-eq2088ns AMD Ryzen 7 5700U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 649.01},
#  {'Laptop': 'MSI Vector GP77 13VG-021XES Intel Core i7-13700H/32GB/1TB SSD/RTX 4070/17.3"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Vector',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4070',
#   'Screen': 17.3,
#   'Touch': 'No',
#   'Final Price': 2499.0},
#  {'Laptop': 'ASUS VivoBook 15 F1500EA-EJ3067W Intel Core i7-1165G7/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 859.0},
#  {'Laptop': 'MSI Creator M16 B12UDX-809XES Intel Core i7-12650H/32GB/1TB SSD/RTX 3050/16"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Creator',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 1499.01},
#  {'Laptop': 'Apple Macbook Pro Apple M2/8GB/256GB SSD/GPU Deca Core/13.3" Plata',
#   'Status': 'New',
#   'Brand': 'Apple',
#   'Model': 'MacBook Pro',
#   'CPU': 'Apple M2',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 13.3,
#   'Touch': 'No',
#   'Final Price': 1599.0},
#  {'Laptop': 'ASUS TUF Gaming A15 2023 FA507XI-LP024 AMD Ryzen 9 7940HS/32GB/512GB SSD/RTX 4070/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'TUF',
#   'CPU': 'AMD Ryzen 9',
#   'RAM': 32,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4070',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1699.01},
#  {'Laptop': 'MSI Katana 15 B13VFK-031XES Intel Core i7-13620H/16GB/1TB SSD/RTX 4060/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Katana',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4060',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1699.0},
#  {'Laptop': 'HP Victus 16-d1021ns Intel Core i7-12700H/16GB/512GB SSD/RTX 3050Ti/16.1"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Victus',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 16.1,
#   'Touch': 'No',
#   'Final Price': 1199.0},
#  {'Laptop': 'MSI Modern 14 C13M-426XES Intel Core i7-1355U/16GB/1TB SSD/14"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Modern',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 999.0},
#  {'Laptop': 'MSI Modern 15 B12M-430XES Intel Core i3-1215U/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Modern',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 499.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ALC6 AMD Ryzen 3 5300U/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 499.0},
#  {'Laptop': 'MSI Prestige 14H B12UCX-414XES Intel Core i5-12450H/16GB/512GB SSD/RTX 2050/14"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Prestige',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 2050',
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 999.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ITL6 Intel Core i7-1165G7/16GB/512 GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 749.0},
#  {'Laptop': 'Lenovo ThinkBook 15 G2 ITL Intel Core i5-1135G7/8 GB/256GB SSD/15.6" Gris',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'ThinkBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 879.0},
#  {'Laptop': 'MSI Prestige 14H B12UCX-413XES Intel Core i7-12650H/16GB/1TB SSD/RTX 2050/14"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Prestige',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 2050',
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 1489.0},
#  {'Laptop': 'HP Pavilion 15-eg2004ns Intel Core i7-1255U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Pavilion',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 999.0},
#  {'Laptop': 'HP Victus 15-fa0026ns Intel Core i5-12450H/16GB/512GB SSD/GTX 1650/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Victus',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'GTX 1650',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 999.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ITL6 Intel Core i5-1155G7/8 GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 589.0},
#  {'Laptop': 'Lenovo ThinkBook 14 G4 IAP Intel Core i5-1235U/8GB/256GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'ThinkBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 959.0},
#  {'Laptop': 'HP Victus 15-fa0004ns Intel Core i5-12500H/16GB/512GB SSD/GTX 1650/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Victus',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'GTX 1650',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1039.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ALC6 AMD Ryzen 5 5500U/8GB/512GBSSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 599.0},
#  {'Laptop': 'HP 15S-fq5094ns Intel Core i7-1255U/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'Intel Core i7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 739.01},
#  {'Laptop': 'MSI Stealth 16 Studio A13VF-038XES Intel Core i7-13700H/32GB/1TB SSD/RTX 4060/16"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Stealth',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4060',
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 2449.0},
#  {'Laptop': 'Acer Aspire 5 A515-57-76BV Intel Core i7-1255U/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Acer',
#   'Model': 'Aspire',
#   'CPU': 'Intel Core i7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 839.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ALC6 AMD Ryzen 3 5300U/8 GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 499.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ALC6 AMD Ryzen 7 5700U/8 GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 699.0},
#  {'Laptop': 'MSI Pulse 15 B13VFK-448XES Intel Core i9-13900H/32GB/1TB SSD/RTX 4060/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Pulse',
#   'CPU': 'Intel Core i9',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4060',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 2399.01},
#  {'Laptop': 'Lenovo IdeaPad 1 15ADA7 AMD 3020e/4GB/128GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD 3020e',
#   'RAM': 4,
#   'Storage': 128,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 442.99},
#  {'Laptop': 'Lenovo IdeaPad 3 15ALC6 AMD Ryzen 5 5500U/8 GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 689.01},
#  {'Laptop': 'Lenovo IdeaPad 3 15ITL6 Intel Core i5-1155G7/16 GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 749.0},
#  {'Laptop': 'Lenovo IdeaPad 1 15ADA7 AMD 3020e/4GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD 3020e',
#   'RAM': 4,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 321.99},
#  {'Laptop': 'MSI Modern 15 B11M-043XES Intel Core i5-1155G7/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Modern',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 599.0},
#  {'Laptop': 'ASUS ZenBook 13 OLED UX325EA-KG448W Intel Core i7-1165G7/16GB/512GB SSD/13.3"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ZenBook',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 13.3,
#   'Touch': 'No',
#   'Final Price': 1199.0},
#  {'Laptop': 'ASUS TUF Gaming F15 FX506HF-HN004 Intel Core i5-11400H/16GB/512GB SSD/RTX 2050/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'TUF',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 2050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 949.0},
#  {'Laptop': 'ASUS VivoBook F1605PA-MB125W Intel Core i5-11300H/16GB/512GB SSD/16"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 799.0},
#  {'Laptop': 'Razer Blade 15 Advanced Model QHD Intel Core i7-12800H/16GB/1TB SSD/RTX 3070Ti/15.6"',
#   'Status': 'New',
#   'Brand': 'Razer',
#   'Model': 'Blade',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3070',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 3299.99},
#  {'Laptop': 'Medion Akoya E15301 AMD Ryzen 7 3700U/8 GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Medion',
#   'Model': 'Akoya',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 478.99},
#  {'Laptop': 'ASUS ExpertBook B1 B1502CBA-EJ0469X Intel Core i5-1235U/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ExpertBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 989.0},
#  {'Laptop': 'Lenovo IdeaPad 1 15ADA7 AMD Ryzen 3 3250U/8 GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 439.99},
#  {'Laptop': 'HP 15S-eq2089ns AMD Ryzen 3 5300U/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'AMD Ryzen 3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 529.0},
#  {'Laptop': 'ASUS VivoBook F1605PA-MB143 Intel Core i7-11370H/8GB/512GB SSD/16"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 709.0},
#  {'Laptop': 'ASUS Vivobook Go E1504FA-BQ204W AMD Ryzen 5 7520U/8GB/512GB SSD/Radeon 610M/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': '610 M',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 509.99},
#  {'Laptop': 'Lenovo IdeaPad 1 15ALC7 AMD Ryzen 5 5500U/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 659.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ITL6 Intel Core i7-1165G7/16GB/512GBSSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 749.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ALC6 AMD Ryzen 7 5700U/8GB/512 GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 589.0},
#  {'Laptop': 'Lenovo IdeaPad 1 15ALC7 AMD Ryzen 5 5500U/8 GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 549.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ALC6 AMD Ryzen 3 5300U/8GB/256 GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 459.0},
#  {'Laptop': 'ASUS VivoBook F1605PA-MB124W Intel Core i7-11370H/8GB/512GB SSD/16"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 819.0},
#  {'Laptop': 'ASUS VivoBook F1605PA-MB146 Intel Core i5-11300H/8GB/512GB SSD/16"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 609.01},
#  {'Laptop': 'ASUS ZenBook 14 UM425QA-KI252 AMD Ryzen 7 5800H/16GB/512GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ZenBook',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 999.0},
#  {'Laptop': 'Acer Aspire 3 A315-59-504M Intel Core i5-1235U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Acer',
#   'Model': 'Aspire',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 739.01},
#  {'Laptop': 'Lenovo IdeaPad Gaming 3 15IAH7 Intel Core i7-12700H/16GB/512GB SSD/RTX3060/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3060',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1399.0},
#  {'Laptop': 'ASUS VivoBook F1500EA-EJ3070W Intel Core i5-1135G7/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 759.01},
#  {'Laptop': 'Lenovo IdeaPad 1 15ALC7 AMD Ryzen 5 5500U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 729.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ITL6 Intel Core i5-1155G7/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 749.0},
#  {'Laptop': 'HP 255 G9 AMD Athlon 3020e/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '255',
#   'CPU': 'AMD Athlon',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 349.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ITL6 Intel Core i3-1115G4/8 GB/256GBSSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 479.0},
#  {'Laptop': 'HP 255 G9 AMD Ryzen 5 5625U/16GB/512 GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '255',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 873.29},
#  {'Laptop': 'Lenovo IdeaPad 5 15ALC05 AMD Ryzen 5 5500U/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 589.0},
#  {'Laptop': 'ASUS Chromebook CX1400CKA-EK0138 Intel Celeron N4500/8GB/64GB eMMC/14"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'Chromebook',
#   'CPU': 'Intel Celeron',
#   'RAM': 8,
#   'Storage': 64,
#   'Storage type': 'eMMC',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 399.01},
#  {'Laptop': 'Lenovo Legion 5 15ACH6H AMD Ryzen 7 5800H/16GB/512GB SSD/RTX3050Ti/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'Legion',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1079.01},
#  {'Laptop': 'Lenovo IdeaPad 3 15ITL6 Intel Core i5-1135G7/8GB/512GB SSD/15.6" Azul',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 649.0},
#  {'Laptop': 'Lenovo IdeaPad Gaming 3 15ACH6 AMD Ryzen 7 5800H/16GB/512GB SSD/RTX 3050Ti/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 999.0},
#  {'Laptop': 'Lenovo ThinkBook 14 G2 ITL Intel Core i5-1135G7/16 GB/512GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'ThinkBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 1019.0},
#  {'Laptop': 'MSI Pulse GL76 12UEK-828XES Intel Core i7-12700H/32GB/1TB SSD/RTX 3060/17.3"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Pulse',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3060',
#   'Screen': 17.3,
#   'Touch': 'No',
#   'Final Price': 1499.0},
#  {'Laptop': 'Apple Macbook Air Apple M2/8GB/256GB SSD/GPU Octa Core/13.6" Gris Espacial',
#   'Status': 'New',
#   'Brand': 'Apple',
#   'Model': 'MacBook Air',
#   'CPU': 'Apple M2',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 13.6,
#   'Touch': 'No',
#   'Final Price': 1519.0},
#  {'Laptop': 'Acer Aspire 3 A317-53-53U0 Intel Core i5-1135G7/8GB/512GB SSD/17.3"',
#   'Status': 'New',
#   'Brand': 'Acer',
#   'Model': 'Aspire',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 17.3,
#   'Touch': 'No',
#   'Final Price': 729.0},
#  {'Laptop': 'MSI Raider GE68HX 13VF-045XES Intel Core i9-13950HX/32GB/1TB SSD/RTX 4060/16"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Raider',
#   'CPU': 'Intel Core i9',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4060',
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 2599.0},
#  {'Laptop': 'HP 15S-fq4042ns Intel Core i7-1195G7/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'Intel Core i7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 699.0},
#  {'Laptop': 'Lenovo Legion 5 15IAH7H Intel Core i7-12700H/16GB/512GB SSD/RTX3060/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'Legion',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3060',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1599.0},
#  {'Laptop': 'HP ProBook 450 G8 Intel Core i5-1135G7/8 GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'ProBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 739.01},
#  {'Laptop': 'ASUS VivoBook 15 F1500EA-EJ3021 Intel Core i5-1135G7/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 709.0},
#  {'Laptop': 'Lenovo IdeaPad Gaming 3 15IAH7 Intel Core i5-12500H/16 GB/512GB SSD/RTX3050Ti/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1059.0},
#  {'Laptop': 'MSI Modern 14 C13M-447XES Intel Core i5-1335U/16GB/512GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Modern',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 799.0},
#  {'Laptop': 'MSI Modern 14 C12M-017XES Intel Core i7-1255U/16GB/512GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Modern',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 999.0},
#  {'Laptop': 'Lenovo IdeaPad 3 15ITL6 Intel Core i7-1165G7/16 GB/512GB SSD/15.6"',
#   'Status': 'Refurbished',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 899.0},
#  {'Laptop': 'MSI Pulse 15 B13VGK-433XES Intel Core i9-13900H/32GB/1TB SSD/RTX 4070/15.6"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Pulse',
#   'CPU': 'Intel Core i9',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4070',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 2299.0},
#  {'Laptop': "MSI Stealth 15 A13VF-028XES Intel Core i7-13620H/32GB/1TB SSD/RTX 4060/15.6''",
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Stealth',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4060',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1899.0},
#  {'Laptop': 'ASUS Chromebook CX1400FKA-EC0078 Intel Celeron N4500/8GB/64GB eMMC/14" Táctil',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'Chromebook',
#   'CPU': 'Intel Celeron',
#   'RAM': 8,
#   'Storage': 64,
#   'Storage type': 'eMMC',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'Yes',
#   'Final Price': 449.0},
#  {'Laptop': 'Lenovo V15 G2 ITL Intel Core i5-1135G7/16 GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'V15',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 699.0},
#  {'Laptop': 'ASUS Chromebook CX1400CNA-BV0210 Intel Celeron N3350/8GB/32GB/14"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'Chromebook',
#   'CPU': 'Intel Celeron',
#   'RAM': 8,
#   'Storage': 32,
#   'Storage type': nan,
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 349.0},
#  {'Laptop': 'MSI Vector GP68HX 12VH-009XES Intel Core i9-12900HX/32GB/1TB SSD/RTX 4080/16"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Vector',
#   'CPU': 'Intel Core i9',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4080',
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 2599.0},
#  {'Laptop': 'HP 15S-fq5075ns Intel Core i5-1235U/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 579.01},
#  {'Laptop': 'Acer Aspire 3 A315-59-56GV Intel Core i5-1235U/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Acer',
#   'Model': 'Aspire',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 749.0},
#  {'Laptop': 'ASUS ExpertBook P1512CEA-EJ0083X Intel Core i3-1115G4/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ExpertBook',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 549.0},
#  {'Laptop': 'Lenovo IdeaPad Gaming 3 15ACH6 AMD Ryzen 5 5600H/16GB/512GB SSD/RTX3050/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 979.0},
#  {'Laptop': 'ASUS ZenBook 14 OLED UM3402YA-KM513 AMD Ryzen 5 7530U/16GB/512GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ZenBook',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 969.0},
#  {'Laptop': 'Lenovo IdeaPad Gaming 3 15IAH7 Intel Core i5-12500H/16GB/512GB SSD/RTX3050/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1099.0},
#  {'Laptop': 'Lenovo Legion 5 15ITH6H Intel Core i5-11400H/16GB/512GB SSD/RTX3060/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'Legion',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3060',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1319.01},
#  {'Laptop': 'Lenovo IdeaPad Flex 5 14ALC05 AMD Ryzen 5 5500U/16GB/512GB SSD/14" Táctil',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'Yes',
#   'Final Price': 799.0},
#  {'Laptop': 'Apple MacBook Air Apple M1/8GB/256GB SSD/GPU Hepta Core/13.3" Plata',
#   'Status': 'New',
#   'Brand': 'Apple',
#   'Model': 'MacBook Air',
#   'CPU': 'Apple M1',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 13.3,
#   'Touch': 'No',
#   'Final Price': 1219.0},
#  {'Laptop': 'Lenovo IdeaPad Gaming 3 15ACH6 AMD Ryzen 5 5600H/16 GB/512GB SSD/GTX1650/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'GTX 1650',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 879.0},
#  {'Laptop': 'MSI Prestige 14H B12UCX-427XES Intel Core i7-12650H/32GB/1TB SSD/RTX 2050/14"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Prestige',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 2050',
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 1359.0},
#  {'Laptop': 'ASUS F515EA-EJ1858W Intel Core i7-1165G7/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'F515',
#   'CPU': 'Intel Core i7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 839.0},
#  {'Laptop': 'Gigabyte G5 KF-E3ES313SD Intel Core i5-12500H/16GB/512GB SSD/RTX 4060/15.6"',
#   'Status': 'New',
#   'Brand': 'Gigabyte',
#   'Model': 'G5',
# ...
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 494.81},
#  {'Laptop': 'HP EliteBook 840 G8 Intel Core i5-1135G7/8 GB/256GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'EliteBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 750.73},
#  {'Laptop': 'HP Victus 16-e1017ns AMD Ryzen 5 6600H/16GB/512GB SSD/RTX 3050/16.1"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Victus',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 16.1,
#   'Touch': 'No',
#   'Final Price': 1120.0},
#  {'Laptop': 'Lenovo ThinkPad L15 Gen 2 Intel Core i5-1145G7/16GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'ThinkPad',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 969.0},
#  {'Laptop': 'Apple MacBook Air Intel Core i5/8GB/512GB SSD/13.3" Plata',
#   'Status': 'Refurbished',
#   'Brand': 'Apple',
#   'Model': 'MacBook Air',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 13.3,
#   'Touch': 'No',
#   'Final Price': 895.0},
#  {'Laptop': 'MSI Raider GE78HX 13VI-063ES Intel Core i9-13980HX/64GB/2TB SSD/RTX 4090/17"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Raider',
#   'CPU': 'Intel Core i9',
#   'RAM': 64,
#   'Storage': 2000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4090',
#   'Screen': 17.0,
#   'Touch': 'No',
#   'Final Price': 5199.0},
#  {'Laptop': 'Medion Classmate Pro E14409 MD62157 Intel Core i3-1005G1/4GB/128GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'Medion',
#   'Model': 'Classmate Pro',
#   'CPU': 'Intel Core i3',
#   'RAM': 4,
#   'Storage': 128,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 273.61},
#  {'Laptop': 'Lenovo V15 G2 ALC AMD Ryzen 7-5700U/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'V15',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 628.99},
#  {'Laptop': 'HP Victus 16-E0073NS AMD Ryzen 7 5800H/8GB/512GB SSD/RX 5500M/16.1"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'Victus',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'Radeon Pro 5500M',
#   'Screen': 16.1,
#   'Touch': 'No',
#   'Final Price': 982.0},
#  {'Laptop': 'Acer Aspire 3 A315-56-519X Intel Core i5-1035G1/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Acer',
#   'Model': 'Aspire',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 474.86},
#  {'Laptop': 'Asus ZenBook Flip 13 UX363JA-EM189T Intel Core i5-1035G4/16GB/512GB SSD/13.3" Táctil',
#   'Status': 'Refurbished',
#   'Brand': 'Asus',
#   'Model': 'ZenBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 13.3,
#   'Touch': 'Yes',
#   'Final Price': 678.39},
#  {'Laptop': 'Dell Vostro 3420 Intel Core i5-1135G7/8GB/256GB SSD/14" (PT)',
#   'Status': 'New',
#   'Brand': 'Dell',
#   'Model': 'Vostro',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 697.36},
#  {'Laptop': 'Lenovo IdeaPad Flex 5 14ITL05 Intel Core i5-1135G7/8GB/512GB SSD/14" Táctil',
#   'Status': 'Refurbished',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'Yes',
#   'Final Price': 799.0},
#  {'Laptop': 'ASUS VivoBook Flip 14 TP401MA-EC448W Intel Celeron N4020/4GB/256GB SSD/14" Táctil',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Celeron',
#   'RAM': 4,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'Yes',
#   'Final Price': 398.01},
#  {'Laptop': 'Asus Chromebook C204MA-GJ0342 Intel Celeron N4020/4GB/32GB eMMC/11.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'Chromebook',
#   'CPU': 'Intel Celeron',
#   'RAM': 4,
#   'Storage': 32,
#   'Storage type': 'eMMC',
#   'GPU': nan,
#   'Screen': 11.6,
#   'Touch': 'No',
#   'Final Price': 239.25},
#  {'Laptop': 'HP 15S-EQ1126NS AMD Athlon Silver 3050U/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'AMD Athlon',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 384.27},
#  {'Laptop': 'HP 255 G7 AMD Ryzen 3 3200U/8 GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '255',
#   'CPU': 'AMD Ryzen 3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 556.22},
#  {'Laptop': 'Lenovo 100e Intel Celeron N4000/4GB/128GB SSD/11.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': '100e',
#   'CPU': 'Intel Celeron',
#   'RAM': 4,
#   'Storage': 128,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 11.6,
#   'Touch': 'No',
#   'Final Price': 350.0},
#  {'Laptop': 'Lenovo ThinkPad P16s Gen 1 Intel Core i7-1260P/32GB/1TB SSD/Quadro T550/16"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'ThinkPad',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'T 550',
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 2575.0},
#  {'Laptop': 'Lenovo Thinkpad P17 Gen 2 Intel Core i7-11850H/32GB/1TB SSD/RTX A3000/17.3"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'ThinkPad',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX A3000',
#   'Screen': 17.3,
#   'Touch': 'No',
#   'Final Price': 3496.86},
#  {'Laptop': 'MSI Katana 17 B13VEK-298ES Intel Core i7-13620H/16GB/1TB SSD/RTX 4050/17.3"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Katana',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4050',
#   'Screen': 17.3,
#   'Touch': 'No',
#   'Final Price': 1496.56},
#  {'Laptop': 'Microsoft Surface Go 3 Business 4G LTE Intel Core i3-10100Y/8 GB/128GB SSD/10.5" Táctil Platino',
#   'Status': 'New',
#   'Brand': 'Microsoft',
#   'Model': 'Surface Go',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 128,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 10.5,
#   'Touch': 'Yes',
#   'Final Price': 853.59},
#  {'Laptop': 'Vant Moove3-14 Intel Core i5-1135G7/16GB/500GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'Vant',
#   'Model': 'Moove',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 500,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 645.99},
#  {'Laptop': 'MSI Pulse GL66 12UEK-086XES Intel Core i7-12700H/16GB/1TB SSD/RTX 3060/15.6"',
#   'Status': 'Refurbished',
#   'Brand': 'MSI',
#   'Model': 'Pulse',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3060',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1649.0},
#  {'Laptop': 'Asus F515JA-BR1164T Intel Core i3-1005G1/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'F515',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 650.36},
#  {'Laptop': 'Lenovo ThinkBook 13s G4 Intel Core i5-1240P/16GB/512GB SSD/13.3"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'ThinkBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 13.3,
#   'Touch': 'No',
#   'Final Price': 1310.61},
#  {'Laptop': 'ASUS ExpertBook B1 B1502CBA-EJ0426X Intel Core i7-1255U/16GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ExpertBook',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 950.53},
#  {'Laptop': 'Asus ROG Zephyrus M GU603HR-K8009T Intel Core i7-11800H/32GB/1TB SSD/RTX 3070/16"',
#   'Status': 'Refurbished',
#   'Brand': 'Asus',
#   'Model': 'ROG',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3070',
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 2599.0},
#  {'Laptop': 'HP 250 G9 Intel Celeron N4500/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '250',
#   'CPU': 'Intel Celeron',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 357.64},
#  {'Laptop': 'HP 250 G9 Intel Core i3-1215U/8GB/256GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '250',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 634.05},
#  {'Laptop': 'HP EliteBook 860 G9 Intel Core i7-1255U/32GB/1TB SSD/16"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': 'EliteBook',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 1735.35},
#  {'Laptop': 'Alurin Flex Advance Intel Core i5-1155G7/16GB/500GB SSD/14" + Windows 11 Home',
#   'Status': 'New',
#   'Brand': 'Alurin',
#   'Model': 'Flex Advance',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 500,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 629.01},
#  {'Laptop': 'Lenovo ThinkPad T480s Intel Core i7-8565U/8GB/256GB SSD/14"',
#   'Status': 'Refurbished',
#   'Brand': 'Lenovo',
#   'Model': 'ThinkPad',
#   'CPU': 'Intel Core i7',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 711.95},
#  {'Laptop': 'Apple MacBook Air Intel Core i5/8GB/128GB SSD/13" Plata',
#   'Status': 'Refurbished',
#   'Brand': 'Apple',
#   'Model': 'MacBook Air',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 128,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 13.0,
#   'Touch': 'No',
#   'Final Price': 391.17},
#  {'Laptop': 'Lenovo IdeaPad Flex 5 14ALC05 AMD Ryzen 7 5700U/16GB/512GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'AMD Ryzen 7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 1058.0},
#  {'Laptop': 'MSI Creator Z17 HX Studio A13VGT-044ES Intel Core i9-13950HX/32GB/1TB SSD/RTX 4070/17" Táctil',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Creator',
#   'CPU': 'Intel Core i9',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4070',
#   'Screen': 17.0,
#   'Touch': 'Yes',
#   'Final Price': 3175.35},
#  {'Laptop': 'MSI Katana 17 B13VEK-294XES Intel Core i7-13620H/16GB/1TB SSD/RTX 4050/17.3"',
#   'Status': 'New',
#   'Brand': 'MSI',
#   'Model': 'Katana',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4050',
#   'Screen': 17.3,
#   'Touch': 'No',
#   'Final Price': 1496.56},
#  {'Laptop': 'Lenovo IdeaPad D330-10IGM Intel Celeron N4000/4GB/64GB eMMC/10.1" Táctil',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'IdeaPad',
#   'CPU': 'Intel Celeron',
#   'RAM': 4,
#   'Storage': 64,
#   'Storage type': 'eMMC',
#   'GPU': nan,
#   'Screen': 10.1,
#   'Touch': 'Yes',
#   'Final Price': 324.0},
#  {'Laptop': 'Microsoft Surface Laptop 5 Negro Intel Evo Core i7-1265U/16GB/512GB SSD/15" Táctil',
#   'Status': 'New',
#   'Brand': 'Microsoft',
#   'Model': 'Surface Laptop',
#   'CPU': 'Intel Evo Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.0,
#   'Touch': 'Yes',
#   'Final Price': 2310.0},
#  {'Laptop': 'Microsoft Surface Laptop Studio Intel Core i7-11370H/32GB/1TB SSD/RTX 3050Ti/14.4" Táctil Platino',
#   'Status': 'New',
#   'Brand': 'Microsoft',
#   'Model': 'Surface Laptop',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3050',
#   'Screen': 14.4,
#   'Touch': 'Yes',
#   'Final Price': 2799.0},
#  {'Laptop': 'HP 15S-eq2093ns AMD Ryzen 3 5300U/8GB/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'HP',
#   'Model': '15S',
#   'CPU': 'AMD Ryzen 3',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 470.44},
#  {'Laptop': 'Lenovo Legion Pro 7 16IRX8H Intel Core i9-13900HX/32GB/1TB SSD/RTX 4080/16"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'Legion',
#   'CPU': 'Intel Core i9',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 4080',
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 4580.73},
#  {'Laptop': 'Lenovo V14 Intel Core i3-10110U/8GB/256GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'V14',
#   'CPU': 'Intel Core i3',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 484.5},
#  {'Laptop': 'ASUS VivoBook F1500EA-EJ3066W Intel Core i7-1165G7/8GB RAM/512GB SSD/15.6"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i7',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 625.0},
#  {'Laptop': 'ASUS ZenBook 14 UM3402YA-KP287 AMD Ryzen 5 5625U/16GB/512GB SSD/14"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ZenBook',
#   'CPU': 'AMD Ryzen 5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 812.61},
#  {'Laptop': 'ASUS ProArt StudioBook Pro 16 OLED W7600Z3A-L2022X Intel Core i7-12700H/32GB/1TB SSD/RTX A3000/16"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'ProArt',
#   'CPU': 'Intel Core i7',
#   'RAM': 32,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX A3000',
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 2846.0},
#  {'Laptop': 'Acer Predator Helios 300 PH315-54 Intel Core i7-11800H/16GB/1TB SSD/RTX 3070/15.6"',
#   'Status': 'New',
#   'Brand': 'Acer',
#   'Model': 'Predator',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 1000,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3070',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1849.0},
#  {'Laptop': 'Dell Latitude 5330 Intel Core i5-1235U/16GB/512GB SSD/13.3"',
#   'Status': 'New',
#   'Brand': 'Dell',
#   'Model': 'Latitude',
#   'CPU': 'Intel Core i5',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 13.3,
#   'Touch': 'No',
#   'Final Price': 1071.49},
#  {'Laptop': 'Dell Latitude 7490 Intel Core i5-8350U/8GB/512GB SSD/14"',
#   'Status': 'Refurbished',
#   'Brand': 'Dell',
#   'Model': 'Latitude',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 699.0},
#  {'Laptop': 'Lenovo ThinkPad P15 Gen 1 Intel Core i7-10750H/16GB/512GB SSD/Quadro T2000/15.6"',
#   'Status': 'New',
#   'Brand': 'Lenovo',
#   'Model': 'ThinkPad',
#   'CPU': 'Intel Core i7',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'T 2000',
#   'Screen': 15.6,
#   'Touch': 'No',
#   'Final Price': 1670.01},
#  {'Laptop': 'Asus VivoBook F1605PA-MB145 Intel Core i5-11300H/8GB/256GB SSD/16"',
#   'Status': 'New',
#   'Brand': 'Asus',
#   'Model': 'VivoBook',
#   'CPU': 'Intel Core i5',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 16.0,
#   'Touch': 'No',
#   'Final Price': 469.9},
#  {'Laptop': 'Acer Nitro 5 AN517-54-9875 Intel Core i9-11900H/16GB/512GB SSD/RTX 3060/17.3"',
#   'Status': 'New',
#   'Brand': 'Acer',
#   'Model': 'Nitro',
#   'CPU': 'Intel Core i9',
#   'RAM': 16,
#   'Storage': 512,
#   'Storage type': 'SSD',
#   'GPU': 'RTX 3060',
#   'Screen': 17.3,
#   'Touch': 'No',
#   'Final Price': 1495.69},
#  {'Laptop': 'Alurin Go Start Intel Celeron N4020/8GB/256GB SSD/14" + Windows 11 Home',
#   'Status': 'New',
#   'Brand': 'Alurin',
#   'Model': 'Go',
#   'CPU': 'Intel Celeron',
#   'RAM': 8,
#   'Storage': 256,
#   'Storage type': 'SSD',
#   'GPU': nan,
#   'Screen': 14.0,
#   'Touch': 'No',
#   'Final Price': 339.0},
#  ...]

# %%
df.nunique()
# Out:
# Laptop          2160
# Status             2
# Brand             27
# Model            121
# CPU               28
# RAM                9
# Storage           12
# Storage type       2
# GPU               44
# Screen            29
# Touch              2
# Final Price     1440
# dtype: int64

# %%
df.head()
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# 3    No      1199.00
# 4    No       669.01

# %% [markdown]
# # Q5. Maximum final price

# %%
# What's the maximum final price of Dell notebooks in the dataset? 3936
df_Dell['Final Price'].max()
# Out:
# 3936.0

# %%
df_max = df_Dell[df_Dell['Final Price']== df_Dell['Final Price'].max()]

# %%
print(df_max)
# Out:
#                                                  Laptop Status Brand  \
# 1335  Dell Precision 5770 Intel Core i7-12700H/16GB/...    New  Dell
#
#           Model            CPU  RAM  Storage Storage type        GPU  Screen  \
# 1335  Precision  Intel Core i7   16      512          SSD  RTX A2000    17.0
#
#      Touch  Final Price
# 1335   Yes       3936.0

# %%
df_Dell=df[df['Brand']=='Dell']

df_Dell
# Out:
#                                                  Laptop       Status Brand  \
# 161   Dell Vostro 3510 Intel Core i3-1115G4/8 GB/256...          New  Dell
# 271   Dell Vostro 3510 Intel Core i5-1135G7/8 GB/256...          New  Dell
# 281   Dell Vostro 3520 Intel Core i7-1255U/16GB/512G...          New  Dell
# 319   Dell Latitude 3520 Intel Core i5-1135G7/8GB/25...          New  Dell
# 328   Dell Vostro 3510 Intel Core i5-1135G7/16 GB/51...          New  Dell
# ...                                                 ...          ...   ...
# 1843  Dell Vostro 5301 Intel Core i5-1135G7/8GB/256G...  Refurbished  Dell
# 1844  Dell Vostro 5301 Intel Core i5-1135G7/8GB/512G...  Refurbished  Dell
# 1845  Dell Vostro 5502 Intel Core i5-1135G7/8GB/512G...  Refurbished  Dell
# 1846  Dell XPS 13 9300 Intel Core i5-1035G1/8GB/512G...  Refurbished  Dell
# 1847  Dell XPS 7390 Intel Core i7-10510U/16GB/512GB ...  Refurbished  Dell
#
#          Model            CPU  RAM  Storage Storage type  GPU  Screen Touch  \
# 161     Vostro  Intel Core i3    8      256          SSD  NaN    15.6    No
# 271     Vostro  Intel Core i5    8      256          SSD  NaN    15.6    No
# 281     Vostro  Intel Core i7   16      512          SSD  NaN    15.6    No
# 319   Latitude  Intel Core i5    8      256          SSD  NaN    15.6    No
# 328     Vostro  Intel Core i5   16      512          SSD  NaN    15.6    No
# ...        ...            ...  ...      ...          ...  ...     ...   ...
# 1843    Vostro  Intel Core i5    8      256          SSD  NaN    13.3    No
# 1844    Vostro  Intel Core i5    8      512          SSD  NaN    13.3    No
# 1845    Vostro  Intel Core i5    8      512          SSD  NaN    15.6    No
# 1846       XPS  Intel Core i5    8      512          SSD  NaN    13.4    No
# 1847       XPS  Intel Core i7   16      512          SSD  NaN    13.3    No
#
#       Final Price
# 161        599.00
# 271        690.15
# 281        889.00
# 319        789.00
# 328        869.00
# ...           ...
# 1843       420.74
# 1844       511.59
# 1845       549.93
# 1846       699.00
# 1847      1086.88
#
# [84 rows x 12 columns]

# %% [markdown]
# # Q6. Median value of Screen

# %%
# 1.Find the median value of Screen column in the dataset.
df.Screen.median()
# Out:
# 15.6

# %%
df.Screen.describe()
# Out:
# count    2156.000000
# mean       15.168112
# std         1.203329
# min        10.100000
# 25%        14.000000
# 50%        15.600000
# 75%        15.600000
# max        18.000000
# Name: Screen, dtype: float64

# %%
# 2. Next, calculate the most frequent value of the same Screen column.

df.Screen.mode()
# Out:
# 0    15.6
# Name: Screen, dtype: float64

# %%
# 3. Use fillna method to fill the missing values in Screen column with the most frequent value from the previous step.

# %%
df.Screen.replace(' ', '15.6')
# Out:
# 0       15.6
# 1       15.6
# 2       15.6
# 3       15.6
# 4       15.6
#         ...
# 2155    17.3
# 2156    17.3
# 2157    17.3
# 2158    13.4
# 2159    13.4
# Name: Screen, Length: 2160, dtype: float64

# %%
# 4. Now, calculate the median value of Screen once again.

df.Screen.median()
# Out:
# 15.6

# %%
# Hint: refer to existing mode and median functions to complete the task.
No,It is the same value.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[152], line 2
#       1 # Hint: refer to existing mode and median functions to complete the task.
# ----> 2 No ('It is the same value')
#
# NameError: name 'No' is not defined

# %% [markdown]
# # Q7. Sum of weights

# %%
# 1. Select all the "Innjoo" laptops from the dataset.
df_Innjoo=df[df['Brand']=='Innjoo']

# %%
df_Innjoo
# Out:
#                                                  Laptop Status   Brand Model  \
# 1478  InnJoo Voom Excellence Intel Celeron N4020/8GB...    New  Innjoo  Voom
# 1479  InnJoo Voom Excellence Pro Intel Celeron N4020...    New  Innjoo  Voom
# 1480  Innjoo Voom Intel Celeron N3350/4GB/64GB eMMC/...    New  Innjoo  Voom
# 1481  Innjoo Voom Laptop Max Intel Celeron N3350/6GB...    New  Innjoo  Voom
# 1482  Innjoo Voom Laptop Pro Intel Celeron N3350/6GB...    New  Innjoo  Voom
# 1483  Innjoo Voom Pro Intel Celeron N3350/6GB/128GB ...    New  Innjoo  Voom
#
#                 CPU  RAM  Storage Storage type  GPU  Screen Touch  Final Price
# 1478  Intel Celeron    8      256          SSD  NaN    15.6    No       311.37
# 1479  Intel Celeron    8      512          SSD  NaN    15.6    No       392.55
# 1480  Intel Celeron    4       64         eMMC  NaN    14.1    No       251.40
# 1481  Intel Celeron    6       64         eMMC  NaN    14.1    No       383.61
# 1482  Intel Celeron    6      128          SSD  NaN    14.1    No       317.02
# 1483  Intel Celeron    6      128         eMMC  NaN    14.1    No       431.38

# %%
# 2. Select only columns RAM, Storage, Screen.
df_Innjoo[['RAM','Storage','Screen']]
# Out:
#       RAM  Storage  Screen
# 1478    8      256    15.6
# 1479    8      512    15.6
# 1480    4       64    14.1
# 1481    6       64    14.1
# 1482    6      128    14.1
# 1483    6      128    14.1

# %%
# 3. Get the underlying NumPy array. Let's call
x = df_Innjoo[['RAM','Storage','Screen']]
x
# Out:
#       RAM  Storage  Screen
# 1478    8      256    15.6
# 1479    8      512    15.6
# 1480    4       64    14.1
# 1481    6       64    14.1
# 1482    6      128    14.1
# 1483    6      128    14.1

# %%
x.values
# Out:
# array([[  8. , 256. ,  15.6],
#        [  8. , 512. ,  15.6],
#        [  4. ,  64. ,  14.1],
#        [  6. ,  64. ,  14.1],
#        [  6. , 128. ,  14.1],
#        [  6. , 128. ,  14.1]])

# %%
# 4. Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.

# %%
x.values.shape
# Out:
# (6, 3)

# %%
x = x.values

# %%
x = np.array([[  8. , 256. ,  15.6],
       [  8. , 512. ,  15.6],
       [  4. ,  64. ,  14.1],
       [  6. ,  64. ,  14.1],
       [  6. , 128. ,  14.1],
       [  6. , 128. ,  14.1]])

# %%
# calculate the transpose of x
x_T = x.T
xTx = np.matmul(x_T,x)

print (xTx)
# Out:
# [[2.52000e+02 8.32000e+03 5.59800e+02]
#  [8.32000e+03 3.68640e+05 1.73952e+04]
#  [5.59800e+02 1.73952e+04 1.28196e+03]]

# %%
# 5. Compute the inverse of XTX.

xTx_inv = np.linalg.inv(xTx)

print(xTx_inv)
# Out:
# [[ 2.78025381e-01 -1.51791334e-03 -1.00809855e-01]
#  [-1.51791334e-03  1.58286725e-05  4.48052175e-04]
#  [-1.00809855e-01  4.48052175e-04  3.87214888e-02]]

# %%
# 6. Create an array y with values [1100, 1300, 800, 900, 1000, 1100].

y = [1100, 1300, 800, 900, 1000, 1100]

# %%
# 7. Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
#w = ((xTx,xTx_inv),y)
w = np.linalg.solve(xTx, np.matmul(x.T, y))

# %%
w
# Out:
# ((array([[2.52000e+02, 8.32000e+03, 5.59800e+02],
#          [8.32000e+03, 3.68640e+05, 1.73952e+04],
#          [5.59800e+02, 1.73952e+04, 1.28196e+03]]),
#   array([[ 2.78025381e-01, -1.51791334e-03, -1.00809855e-01],
#          [-1.51791334e-03,  1.58286725e-05,  4.48052175e-04],
#          [-1.00809855e-01,  4.48052175e-04,  3.87214888e-02]])),
#  [1100, 1300, 800, 900, 1000, 1100])

# %%
# 8. What's the sum of all the elements of the result?


w.sum()
# Out:
# 91.29988062995699
